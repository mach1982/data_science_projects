# %%
import pandas as pd
import matplotlib as plt
# %matplotlib inline

# %%
pwd
# Out:
# '/home/mach'

# %%
ls
# Out:
# anaconda3/         google-play-store-apps/                superhero.ipynb
# Desktop/           Music/                                 superhero-set/
# Documents/         Pictures/                              Templates/
# Downloads/         Public/                                Untitled1.ipynb
# examples.desktop   R/                                     Untitled.ipynb
# google_play/       snap/                                  Videos/
# Google_Play.ipynb  stack-overflow-2018-developer-survey/

# %%
cd stack-overflow-2018-developer-survey/
# Out:
# /home/mach/stack-overflow-2018-developer-survey

# %%
ls
# Out:
# survey_results_public.csv*  survey_results_schema.csv*

# %%
pwd
# Out:
# '/home/mach/stack-overflow-2018-developer-survey'

# %%
stack_over=pd.read_csv('survey_results_public.csv')
# Out:
# /home/mach/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (8,12,13,14,15,16,50,51,52,53,55,56,57,58,59,60,61,62,63,64,65,66,67,68,69,70,71,72,73,74,75,76,77,78,79,80,81,82,83,84,85,93,94,95,96,97,98,99,100,101,102,103,104,105,106,107,108,109,110,111,112,113,114,115,116,117,118,119,120,121,122,123,124,125,126,127,128) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
stack_over
# Out:
#        Respondent Hobby OpenSource                       Country  \
# 0               1   Yes         No                         Kenya
# 1               3   Yes        Yes                United Kingdom
# 2               4   Yes        Yes                 United States
# 3               5    No         No                 United States
# 4               7   Yes         No                  South Africa
# 5               8   Yes         No                United Kingdom
# 6               9   Yes        Yes                 United States
# 7              10   Yes        Yes                       Nigeria
# 8              11   Yes        Yes                 United States
# 9              16    No        Yes                         India
# 10             17   Yes         No                         Spain
# 11             18   Yes        Yes                         India
# 12             19   Yes         No                       Croatia
# ...

# %%
stack_over.shape
# Out:
# (98855, 129)

# %%
stack_over.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 98855 entries, 0 to 98854
# Columns: 129 entries, Respondent to SurveyEasy
# dtypes: float64(41), int64(1), object(87)
# memory usage: 97.3+ MB

# %%
col_names=list(stack_over.columns.values)
for cn in col_names:
    print("{} has null: {}".format(cn,stack_over[cn].isnull().values.any()))
# Out:
# Respondent has null: False
# Hobby has null: False
# OpenSource has null: False
# Country has null: True
# Student has null: True
# Employment has null: True
# FormalEducation has null: True
# UndergradMajor has null: True
# CompanySize has null: True
# DevType has null: True
# YearsCoding has null: True
# YearsCodingProf has null: True
# JobSatisfaction has null: True
# CareerSatisfaction has null: True
# HopeFiveYears has null: True
# JobSearchStatus has null: True
# LastNewJob has null: True
# AssessJob1 has null: True
# AssessJob2 has null: True
# AssessJob3 has null: True
# AssessJob4 has null: True
# AssessJob5 has null: True
# AssessJob6 has null: True
# AssessJob7 has null: True
# AssessJob8 has null: True
# AssessJob9 has null: True
# AssessJob10 has null: True
# AssessBenefits1 has null: True
# AssessBenefits2 has null: True
# AssessBenefits3 has null: True
# AssessBenefits4 has null: True
# AssessBenefits5 has null: True
# AssessBenefits6 has null: True
# ...

# %%
stack_over['OpenSource'].value_counts()
# Out:
# No     55769
# Yes    43086
# Name: OpenSource, dtype: int64

# %%
stack_over['OpenSource'].value_counts().plot(kind='pie',autopct='%1.0f%%')

# %%
stack_over['Hobby'].value_counts().plot(kind='pie',autopct='%1.0f%%')

# %%
stack_over['Student'].fillna(value='Unknow')
# Out:
# 0                    No
# 1                    No
# 2                    No
# 3                    No
# 4        Yes, part-time
# 5                    No
# 6                    No
# 7                    No
# 8                    No
# 9                    No
# 10                   No
# 11                   No
# 12               Unknow
# 13                   No
# 14       Yes, full-time
# 15                   No
# 16       Yes, full-time
# 17                   No
# 18       Yes, full-time
# 19       Yes, full-time
# 20                   No
# 21                   No
# 22                   No
# 23                   No
# 24                   No
# 25       Yes, full-time
# 26                   No
# 27                   No
# 28                   No
# 29                   No
#               ...
# 98825                No
# 98826                No
# 98827            Unknow
# 98828            Unknow
# 98829    Yes, full-time
# 98830            Unknow
# 98831            Unknow
# ...

# %%
stack_over['Student'].value_counts().plot(kind='pie',autopct='%1.0f%%')

# %%
stack_over['Country'].fillna(value='Unknow')
# Out:
# 0                               Kenya
# 1                      United Kingdom
# 2                       United States
# 3                       United States
# 4                        South Africa
# 5                      United Kingdom
# 6                       United States
# 7                             Nigeria
# 8                       United States
# 9                               India
# 10                              Spain
# 11                              India
# 12                            Croatia
# 13                              India
# 14                        Netherlands
# 15                             Israel
# 16                      United States
# 17                             Sweden
# 18                              India
# 19                              Chile
# 20                          Australia
# 21                      United States
# 22                     United Kingdom
# 23                      United States
# 24                              India
# ...

# %%
stack_over['Country'].value_counts()
# Out:
# United States                            20309
# India                                    13721
# Germany                                   6459
# United Kingdom                            6221
# Canada                                    3393
# Russian Federation                        2869
# France                                    2572
# Brazil                                    2505
# Poland                                    2122
# Australia                                 2018
# Netherlands                               1841
# Spain                                     1769
# Italy                                     1535
# Ukraine                                   1279
# Sweden                                    1164
# Pakistan                                  1050
# China                                     1037
# Switzerland                               1010
# Turkey                                    1004
# Israel                                    1003
# ...

# %%
stack_over['Country'].value_counts().plot(kind='pie',autopct='%1.0f%%')

# %%
stack_over['FormalEducation'].value_counts().plot(kind='pie',autopct='%1.0f%%')

# %%
stack_over['Age'].value_counts().plot(kind='pie',autopct='%1.0f%%')

# %%
stack_over['Gender'].value_counts()
# Out:
# Male                                                                         59458
# Female                                                                        4025
# Non-binary, genderqueer, or gender non-conforming                              284
# Female;Transgender                                                             145
# Male;Non-binary, genderqueer, or gender non-conforming                         128
# Transgender                                                                    105
# Female;Male                                                                     98
# Transgender;Non-binary, genderqueer, or gender non-conforming                   51
# Female;Male;Transgender;Non-binary, genderqueer, or gender non-conforming       50
# Female;Non-binary, genderqueer, or gender non-conforming                        50
# Male;Transgender                                                                29
# ...

# %%
stack_over['Gender'].value_counts().plot(kind='pie',autopct='%1.0f%%')

# %% [markdown]
# ### note find if you remove vaules

# %%
stack_over['Gender'].value_counts().plot(kind='bar')

# %%
stack_over['SexualOrientation'].value_counts().plot(kind='pie',autopct='%1.0f%%')

# %%
stack_over['RaceEthnicity'].value_counts().plot(kind='pie',autopct='%1.0f%%')
