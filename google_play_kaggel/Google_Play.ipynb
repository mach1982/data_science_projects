# %% [markdown]
# # Preliminary Analysis of [Goggle Play Store](https://www.kaggle.com/lava18/google-play-store-apps) Dataset from Kaggle.

# %% [markdown]
# ### Importing Pandas and Matplotlib

# %%
import pandas as pd
import matplotlib as plt
# %matplotlib inline

# %% [markdown]
# ### Importing the Dataset and Intial investagation

# %%
play=pd.read_csv('/home/mach/google_play/googleplaystore.csv')

# %%
play.shape
# Out:
# (10841, 13)

# %%
play.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
play.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
# App               10841 non-null object
# Category          10841 non-null object
# Rating            9367 non-null float64
# Reviews           10841 non-null object
# Size              10841 non-null object
# Installs          10841 non-null object
# Type              10840 non-null object
# Price             10841 non-null object
# Content Rating    10840 non-null object
# Genres            10841 non-null object
# Last Updated      10841 non-null object
# Current Ver       10833 non-null object
# Android Ver       10838 non-null object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %% [markdown]
# ### Checking for nulls

# %%
col_names=list(play.columns.values)
for cn in col_names:
    print("{} has null: {}".format(cn,play[cn].isnull().values.any()))
# Out:
# App has null: False
# Category has null: False
# Rating has null: True
# Reviews has null: False
# Size has null: False
# Installs has null: False
# Type has null: True
# Price has null: False
# Content Rating has null: True
# Genres has null: False
# Last Updated has null: False
# Current Ver has null: True
# Android Ver has null: True

# %% [markdown]
# ### Insights:

# %% [markdown]
# ### Investaging the Categorys

# %%
play['Category'].value_counts()
# Out:
# FAMILY                 1972
# GAME                   1144
# TOOLS                   843
# MEDICAL                 463
# BUSINESS                460
# PRODUCTIVITY            424
# PERSONALIZATION         392
# COMMUNICATION           387
# SPORTS                  384
# LIFESTYLE               382
# FINANCE                 366
# HEALTH_AND_FITNESS      341
# PHOTOGRAPHY             335
# SOCIAL                  295
# NEWS_AND_MAGAZINES      283
# SHOPPING                260
# TRAVEL_AND_LOCAL        258
# DATING                  234
# BOOKS_AND_REFERENCE     231
# VIDEO_PLAYERS           175
# EDUCATION               156
# ENTERTAINMENT           149
# MAPS_AND_NAVIGATION     137
# FOOD_AND_DRINK          127
# HOUSE_AND_HOME           88
# LIBRARIES_AND_DEMO       85
# AUTO_AND_VEHICLES        85
# WEATHER                  82
# ART_AND_DESIGN           65
# EVENTS                   64
# PARENTING                60
# COMICS                   60
# BEAUTY                   53
# ...

# %%
play['Category'].value_counts().plot(kind='bar')

# %% [markdown]
# #### Insights: The  catagory wityh the highest number of apps is Family, flowwed by games .

# %% [markdown]
# ### Free Vs Paid

# %%
play['Type'].value_counts().plot(kind='pie',autopct='%1.0f%%')

# %% [markdown]
# #### Insights: Only 7 % of Apps are paid

# %% [markdown]
# ### Analysis of the Content Rating

# %%
play['Content Rating'].value_counts().plot(kind='pie',autopct='%1.0f%%')

# %%
play['Content Rating'].value_counts().plot(kind='bar')

# %% [markdown]
#  #### Insights:  'Everyone' is the highest , and nealy times more than that of the 'Teen rating'

# %% [markdown]
# ### Analysis of the Installs

# %%
play['Installs'].value_counts().plot(kind='pie',autopct='%1.0f%%')

# %% [markdown]
# #### Insights : Apss with 1,000,000 + install have highest precentages

# %% [markdown]
# ### Satistical information on the the 'Rating'

# %%
play['Rating'].describe()
# Out:
# count    9367.000000
# mean        4.193338
# std         0.537431
# min         1.000000
# 25%         4.000000
# 50%         4.300000
# 75%         4.500000
# max        19.000000
# Name: Rating, dtype: float64
