# %% [markdown]
# # Preliminary Analysis of [Superheros](https://www.kaggle.com/adityapatil673/superheroes-their-characteristics/data) Dataset from Kaggle.

# %% [markdown]
# ### Import Pandas , and Matplotlib

# %%
import pandas as pd
import matplotlib as plt
# %matplotlib inline

# %% [markdown]
# ### Import my Dataset that I got at Kaggel:

# %%
super_info_df=pd.read_csv('/home/mach/superhero-set/heroes_information.csv')

# %% [markdown]
# ### Investage the "shape" of the dataset , that is how many colums(11) and rows(734)

# %%
super_info_df.shape
# Out:
# (734, 11)

# %% [markdown]
# ### Basic information

# %%
super_info_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 734 entries, 0 to 733
# Data columns (total 11 columns):
# Unnamed: 0    734 non-null int64
# name          734 non-null object
# Gender        734 non-null object
# Eye color     734 non-null object
# Race          734 non-null object
# Hair color    734 non-null object
# Height        734 non-null float64
# Publisher     719 non-null object
# Skin color    734 non-null object
# Alignment     734 non-null object
# Weight        732 non-null float64
# dtypes: float64(2), int64(1), object(8)
# memory usage: 63.2+ KB

# %% [markdown]
# ### investagating how many null vaules,

# %%
col_names=list(super_info_df.columns.values)
for cn in col_names:
    print("{} has null: {}".format(cn,super_info_df[cn].isnull().values.any()))
# Out:
# Unnamed: 0 has null: False
# name has null: False
# Gender has null: False
# Eye color has null: False
# Race has null: False
# Hair color has null: False
# Height has null: False
# Publisher has null: True
# Skin color has null: False
# Alignment has null: False
# Weight has null: True

# %%
super_info_df.head(50)
# Out:
#     Unnamed: 0               name  Gender Eye color               Race  \
# 0            0             A-Bomb    Male    yellow              Human
# 1            1         Abe Sapien    Male      blue      Icthyo Sapien
# 2            2           Abin Sur    Male      blue            Ungaran
# 3            3        Abomination    Male     green  Human / Radiation
# 4            4            Abraxas    Male      blue      Cosmic Entity
# 5            5      Absorbing Man    Male      blue              Human
# 6            6        Adam Monroe    Male      blue                  -
# 7            7       Adam Strange    Male      blue              Human
# 8            8           Agent 13  Female      blue                  -
# 9            9          Agent Bob    Male     brown              Human
# 10          10         Agent Zero    Male         -                  -
# 11          11         Air-Walker    Male      blue                  -
# ...

# %% [markdown]
# ### As '-' not reconised as a null vaule replace it  with 'unknown', and created a new data frame called super_info_df_n

# %%
super_info_df_n=super_info_df.replace('-','Unknown')

# %% [markdown]
# ### The last 100 rows

# %%
super_info_df_n.tail(50)
# Out:
#      Unnamed: 0             name   Gender Eye color            Race  \
# 684         684         Vagabond   Female      blue         Unknown
# 685         685     Valerie Hart   Female     hazel         Unknown
# 686         686         Valkyrie   Female      blue         Unknown
# 687         687         Vanisher     Male     green         Unknown
# 688         688           Vegeta     Male   Unknown          Saiyan
# 689         689            Venom     Male      blue        Symbiote
# 690         690         Venom II     Male     brown         Unknown
# 691         691        Venom III     Male     brown        Symbiote
# 692         692        Venompool     Male   Unknown        Symbiote
# 693         693       Vertigo II   Female      blue         Unknown
# 694         694             Vibe     Male     brown           Human
# 695         695       Vindicator   Female     green           Human
# 696         696       Vindicator     Male   Unknown         Unknown
# ...

# %% [markdown]
# ### Investage age the Gender of the Superheros

# %%
super_info_df_n['Gender'].value_counts()
# Out:
# Male       505
# Female     200
# Unknown     29
# Name: Gender, dtype: int64

# %%
super_info_df_n['Gender'].value_counts().plot(kind='pie',autopct='%1.0f%%')

# %% [markdown]
# ## Insights: There are just under 3 thimes more male suerper heros to female,

# %% [markdown]
# ### Investaging the Publishers

# %%
print("Thereare {} Publishers".format(super_info_df['Publisher'].count()))
# Out:
# Thereare 719 Publishers

# %%
super_info_df_n['Publisher'].value_counts()
# Out:
# Marvel Comics        388
# DC Comics            215
# NBC - Heroes          19
# Dark Horse Comics     18
# Image Comics          14
# George Lucas          14
# Star Trek              6
# HarperCollins          6
# SyFy                   5
# Team Epic TV           5
# IDW Publishing         4
# Shueisha               4
# Icon Comics            4
# ABC Studios            4
# Wildstorm              3
# Sony Pictures          2
# Universal Studios      1
# South Park             1
# J. R. R. Tolkien       1
# Hanna-Barbera          1
# J. K. Rowling          1
# Titan Books            1
# Rebellion              1
# Microsoft              1
# Name: Publisher, dtype: int64

# %%
super_info_df_n['Publisher'].value_counts().plot(kind='bar')

# %% [markdown]
# ## Insights: Marvel have the most titles , nearly twice as many as DC

# %% [markdown]
# ### Goood V Bad

# %%
super_info_df.Alignment.value_counts()
# Out:
# good       496
# bad        207
# neutral     24
# -            7
# Name: Alignment, dtype: int64

# %%
super_info_df_n['Alignment'].value_counts().plot(kind='pie',autopct='%1.0f%%')

# %%
super_info_df_n.groupby('Publisher').agg({"Alignment":[max]})
# Out:
#                   Alignment
#                         max
# Publisher
# ABC Studios            good
# DC Comics           neutral
# Dark Horse Comics      good
# George Lucas           good
# Hanna-Barbera          good
# HarperCollins          good
# IDW Publishing         good
# Icon Comics            good
# Image Comics           good
# J. K. Rowling          good
# J. R. R. Tolkien        bad
# Marvel Comics       neutral
# Microsoft              good
# NBC - Heroes           good
# Rebellion              good
# Shueisha               good
# Sony Pictures          good
# South Park             good
# Star Trek              good
# SyFy                   good
# Team Epic TV           good
# Titan Books            good
# Universal Studios      good
# Wildstorm              good

# %% [markdown]
# ### Insights :Overall there more good heros than bad heros, ABC Studios have the most good and  J. R. R. Tolkien	the most who are bad

# %% [markdown]
# ### Investage Weight and Height

# %% [markdown]
# ### Using orignal data frmae  we notice that there a number on -99.0 vales for the wight and height and both  cannot  be negatice , I replace the the -99. with 0.00

# %%
super_info_df[['Height','Weight']].head(50)
# Out:
#     Height  Weight
# 0    203.0   441.0
# 1    191.0    65.0
# 2    185.0    90.0
# 3    203.0   441.0
# 4    -99.0   -99.0
# 5    193.0   122.0
# 6    -99.0   -99.0
# 7    185.0    88.0
# 8    173.0    61.0
# 9    178.0    81.0
# 10   191.0   104.0
# 11   188.0   108.0
# 12   193.0    90.0
# 13   180.0    90.0
# 14   -99.0   -99.0
# 15   -99.0   -99.0
# 16   178.0    72.0
# 17   244.0   169.0
# 18   -99.0   -99.0
# 19   257.0   173.0
# 20   188.0   101.0
# 21   -99.0   -99.0
# 22   183.0    68.0
# 23   -99.0   -99.0
# 24   165.0    57.0
# 25   163.0    54.0
# 26   -99.0   -99.0
# 27   183.0    83.0
# 28   180.0    90.0
# 29   211.0   122.0
# 30   183.0    86.0
# 31    61.0   -99.0
# 32   -99.0   -99.0
# 33   229.0   358.0
# 34   213.0   135.0
# 35   -99.0   -99.0
# 36   178.0   106.0
# 37   185.0   146.0
# 38   175.0    63.0
# 39   183.0    68.0
# 40   173.0    57.0
# 41   193.0    98.0
# 42   185.0   270.0
# 43   165.0    59.0
# 44   163.0    50.0
# 45   -99.0   -99.0
# ...

# %% [markdown]
# ### Creat new datafram data for just ght and weigh data

# %%
super_info_df_hw=super_info_df[['Height','Weight']].replace(-99,0.0)

# %%
super_info_df_hw.head(50)
# Out:
#     Height  Weight
# 0    203.0   441.0
# 1    191.0    65.0
# 2    185.0    90.0
# 3    203.0   441.0
# 4      0.0     0.0
# 5    193.0   122.0
# 6      0.0     0.0
# 7    185.0    88.0
# 8    173.0    61.0
# 9    178.0    81.0
# 10   191.0   104.0
# 11   188.0   108.0
# 12   193.0    90.0
# 13   180.0    90.0
# 14     0.0     0.0
# 15     0.0     0.0
# 16   178.0    72.0
# 17   244.0   169.0
# 18     0.0     0.0
# 19   257.0   173.0
# 20   188.0   101.0
# 21     0.0     0.0
# 22   183.0    68.0
# 23     0.0     0.0
# 24   165.0    57.0
# 25   163.0    54.0
# 26     0.0     0.0
# 27   183.0    83.0
# 28   180.0    90.0
# 29   211.0   122.0
# 30   183.0    86.0
# 31    61.0     0.0
# 32     0.0     0.0
# 33   229.0   358.0
# 34   213.0   135.0
# 35     0.0     0.0
# 36   178.0   106.0
# 37   185.0   146.0
# 38   175.0    63.0
# 39   183.0    68.0
# 40   173.0    57.0
# 41   193.0    98.0
# 42   185.0   270.0
# 43   165.0    59.0
# 44   163.0    50.0
# 45     0.0     0.0
# ...

# %% [markdown]
# ### Basic statistac information : Weight

# %%
super_info_df_hw['Weight'].describe()
# Out:
# count    732.00000
# mean      75.90847
# std      100.46474
# min        0.00000
# 25%        0.00000
# 50%       62.00000
# 75%       90.00000
# max      900.00000
# Name: Weight, dtype: float64

# %%
super_info_df_hw['Weight'].hist()

# %% [markdown]
# ### Basic statistac information : Height

# %%
super_info_df_hw['Height'].describe()
# Out:
# count    734.000000
# mean     131.522480
# std       98.701014
# min        0.000000
# 25%        0.000000
# 50%      175.000000
# 75%      185.000000
# max      975.000000
# Name: Height, dtype: float64

# %%
super_info_df_hw['Height'].hist()

# %%
### Insights
